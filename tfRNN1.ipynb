# %% [markdown]
# Training on a single segment (76):

# %%
# IMPORT LIBRARIES:
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard
import time

# SETUP:   
# Prepare train data:
#range1 = [i for i in range(0,95)]
rangeI = np.arange(0,96)
rangeO = [76+1]
dataset_x = pd.read_csv('df.txt', usecols=rangeI, engine='python')
dataset_x = dataset_x.values
dataset_x = dataset_x.astype('float32')
x = np.reshape(dataset_x, (dataset_x.shape[0],1,dataset_x.shape[1]))
dataset_y = pd.read_csv('labels.txt', usecols=rangeO, engine='python')   
dataset_y = dataset_y.values
dataset_y = dataset_y.astype('float32')
#y = np.reshape(dataset_y, (dataset_y.shape[0],1,dataset_y.shape[1]))
y = np.reshape(dataset_y, (dataset_y.shape[0],dataset_y.shape[1]))
x_train = x
y_train = y 
# Prepare test data:
#x_test = pd.read_csv('test_ball.txt', usecols=rangeI, engine='python')
x_test = pd.read_csv('df_test.txt', usecols=rangeI, engine='python')
x_test = x_test.values
x_test = x_test.astype('float32')
x_test = np.reshape(x_test, (x_test.shape[0],1,x_test.shape[1]))
#y_test = pd.read_csv('test_ball.txt', usecols=[96], engine='python')
y_test = pd.read_csv('labels_test.txt', usecols=rangeO, engine='python')   
y_test = y_test.values
y_test = y_test.astype('float32')
y_test = np.reshape(y_test, (y_test.shape[0],y_test.shape[1]))
# Quick test:
#x_test = x_train
#y_test = y_train

num_in = x_train.shape[2]
num_out = y_train.shape[1]

# Build LSTM model:
model = keras.models.Sequential()
model.add(keras.Input(shape=(None, num_in))) #timesteps, seq_length.
#model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.Dense(num_out, activation="sigmoid"))
#print(model.summary)

model.compile(
    loss = keras.losses.BinaryCrossentropy(from_logits=False),
    #optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    metrics = ["accuracy"]    
)

batchSize = 32
verbose = 2
# Train model:
print("Training model ...")
model.fit(x_train, y_train, batch_size=batchSize, epochs=30, verbose=verbose)

# Evaluate model:
print("Done training. Testing model ...")
model.evaluate(x_test, y_test, batch_size=batchSize, verbose=verbose)

# SAVE MODEL:
#model.save('models\tfmodel')

print("Done!")    
# END.
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training model ...
# Epoch 1/30
# 197/197 - 3s - loss: 0.0662 - accuracy: 0.9924 - 3s/epoch - 16ms/step
# Epoch 2/30
# 197/197 - 1s - loss: 0.0021 - accuracy: 0.9998 - 736ms/epoch - 4ms/step
# Epoch 3/30
# 197/197 - 1s - loss: 0.0012 - accuracy: 0.9998 - 727ms/epoch - 4ms/step
# Epoch 4/30
# 197/197 - 1s - loss: 0.0010 - accuracy: 0.9998 - 720ms/epoch - 4ms/step
# Epoch 5/30
# 197/197 - 1s - loss: 9.3294e-04 - accuracy: 0.9998 - 723ms/epoch - 4ms/step
# Epoch 6/30
# 197/197 - 1s - loss: 8.8204e-04 - accuracy: 0.9998 - 723ms/epoch - 4ms/step
# Epoch 7/30
# 197/197 - 1s - loss: 9.0395e-04 - accuracy: 0.9998 - 720ms/epoch - 4ms/step
# Epoch 8/30
# 197/197 - 1s - loss: 8.0006e-04 - accuracy: 0.9998 - 706ms/epoch - 4ms/step
# Epoch 9/30
# 197/197 - 1s - loss: 8.0069e-04 - accuracy: 0.9998 - 737ms/epoch - 4ms/step
# Epoch 10/30
# 197/197 - 1s - loss: 8.2025e-04 - accuracy: 0.9998 - 670ms/epoch - 3ms/step
# Epoch 11/30
# 197/197 - 1s - loss: 6.5262e-04 - accuracy: 0.9998 - 691ms/epoch - 4ms/step
# Epoch 12/30
# 197/197 - 1s - loss: 8.4343e-04 - accuracy: 0.9998 - 684ms/epoch - 3ms/step
# Epoch 13/30
# 197/197 - 1s - loss: 8.1505e-04 - accuracy: 0.9998 - 722ms/epoch - 4ms/step
# Epoch 14/30
# 197/197 - 1s - loss: 8.2788e-04 - accuracy: 0.9998 - 708ms/epoch - 4ms/step
# Epoch 15/30
# 197/197 - 1s - loss: 8.3640e-04 - accuracy: 0.9998 - 780ms/epoch - 4ms/step
# Epoch 16/30
# 197/197 - 1s - loss: 7.5988e-04 - accuracy: 0.9998 - 738ms/epoch - 4ms/step
# Epoch 17/30
# 197/197 - 1s - loss: 6.4837e-04 - accuracy: 0.9998 - 698ms/epoch - 4ms/step
# Epoch 18/30
# 197/197 - 1s - loss: 7.8639e-04 - accuracy: 0.9998 - 726ms/epoch - 4ms/step
# Epoch 19/30
# 197/197 - 1s - loss: 7.5422e-04 - accuracy: 0.9998 - 725ms/epoch - 4ms/step
# Epoch 20/30
# 197/197 - 1s - loss: 7.4334e-04 - accuracy: 0.9998 - 712ms/epoch - 4ms/step
# Epoch 21/30
# 197/197 - 1s - loss: 8.0279e-04 - accuracy: 0.9998 - 702ms/epoch - 4ms/step
# Epoch 22/30
# 197/197 - 1s - loss: 8.3485e-04 - accuracy: 0.9998 - 696ms/epoch - 4ms/step
# Epoch 23/30
# 197/197 - 1s - loss: 7.7695e-04 - accuracy: 0.9998 - 706ms/epoch - 4ms/step
# Epoch 24/30
# 197/197 - 1s - loss: 6.9640e-04 - accuracy: 0.9998 - 681ms/epoch - 3ms/step
# Epoch 25/30
# 197/197 - 1s - loss: 7.6963e-04 - accuracy: 0.9998 - 704ms/epoch - 4ms/step
# Epoch 26/30
# 197/197 - 1s - loss: 6.6822e-04 - accuracy: 0.9998 - 738ms/epoch - 4ms/step
# Epoch 27/30
# 197/197 - 1s - loss: 7.5112e-04 - accuracy: 0.9998 - 732ms/epoch - 4ms/step
# Epoch 28/30
# 197/197 - 1s - loss: 7.1155e-04 - accuracy: 0.9998 - 706ms/epoch - 4ms/step
# Epoch 29/30
# 197/197 - 1s - loss: 6.6617e-04 - accuracy: 0.9998 - 706ms/epoch - 4ms/step
# Epoch 30/30
# 197/197 - 1s - loss: 7.9280e-04 - accuracy: 0.9997 - 701ms/epoch - 4ms/step
# Done training. Testing model ...
# 105/105 - 1s - loss: 0.0013 - accuracy: 0.9997 - 636ms/epoch - 6ms/step
# Done!

# %% [markdown]
# Training on 38 segments:

# %%
# IMPORT LIBRARIES:
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard
import time

# SETUP:   
# Prepare train data:
#range1 = [i for i in range(0,95)]
rangeI = np.arange(0,96)
rangeO = [1+1,2+1,3+1,4+1,29+1,30+1,33+1,36+1,37+1,38+1,39+1,40+1,41+1,45+1,46+1,47+1,48+1,49+1,50+1,51+1,52+1,53+1,54+1,55+1,56+1,57+1,58+1,59+1,60+1,61+1,62+1,63+1,64+1,68+1,69+1,80+1,81+1,88+1]#np.arange(0,93)#[76+1]
dataset_x = pd.read_csv('df.txt', usecols=rangeI, engine='python')
dataset_x = dataset_x.values
dataset_x = dataset_x.astype('float32')
x = np.reshape(dataset_x, (dataset_x.shape[0],1,dataset_x.shape[1]))
dataset_y = pd.read_csv('labels.txt', usecols=rangeO, engine='python')   
dataset_y = dataset_y.values
dataset_y = dataset_y.astype('float32')
#y = np.reshape(dataset_y, (dataset_y.shape[0],1,dataset_y.shape[1]))
y = np.reshape(dataset_y, (dataset_y.shape[0],dataset_y.shape[1]))
x_train = x
y_train = y 
# Prepare test data:
#x_test = pd.read_csv('test_ball.txt', usecols=rangeI, engine='python')
x_test = pd.read_csv('df_test.txt', usecols=rangeI, engine='python')
x_test = x_test.values
x_test = x_test.astype('float32')
x_test = np.reshape(x_test, (x_test.shape[0],1,x_test.shape[1]))
#y_test = pd.read_csv('test_ball.txt', usecols=[96], engine='python')
y_test = pd.read_csv('labels_test.txt', usecols=rangeO, engine='python')   
y_test = y_test.values
y_test = y_test.astype('float32')
y_test = np.reshape(y_test, (y_test.shape[0],y_test.shape[1]))
# Quick test:
#x_test = x_train
#y_test = y_train

num_in = x_train.shape[2]
num_out = y_train.shape[1]

# Build LSTM model:
model = keras.models.Sequential()
model.add(keras.Input(shape=(None, num_in))) #timesteps, seq_length.
#model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.Dense(num_out, activation="sigmoid"))
#print(model.summary)

model.compile(
    loss = keras.losses.BinaryCrossentropy(from_logits=False),
    #optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    metrics = ["accuracy"]    
)

batchSize = 32
verbose = 2
# Train model:
print("Training model ...")
model.fit(x_train, y_train, batch_size=batchSize, epochs=30, verbose=verbose)

# Evaluate model:
print("Done training. Testing model ...")
model.evaluate(x_test, y_test, batch_size=batchSize, verbose=verbose)

# SAVE MODEL:
#model.save('models\tfmodel')

print("Done!")    
# END.
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training model ...
# Epoch 1/30
# 197/197 - 4s - loss: 0.2863 - accuracy: 0.5504 - 4s/epoch - 18ms/step
# Epoch 2/30
# 197/197 - 1s - loss: 0.1648 - accuracy: 0.6929 - 784ms/epoch - 4ms/step
# Epoch 3/30
# 197/197 - 1s - loss: 0.1221 - accuracy: 0.7080 - 780ms/epoch - 4ms/step
# Epoch 4/30
# 197/197 - 1s - loss: 0.1013 - accuracy: 0.7096 - 787ms/epoch - 4ms/step
# Epoch 5/30
# 197/197 - 1s - loss: 0.0929 - accuracy: 0.7001 - 758ms/epoch - 4ms/step
# Epoch 6/30
# 197/197 - 1s - loss: 0.0871 - accuracy: 0.7179 - 797ms/epoch - 4ms/step
# Epoch 7/30
# 197/197 - 1s - loss: 0.0837 - accuracy: 0.7228 - 785ms/epoch - 4ms/step
# Epoch 8/30
# 197/197 - 1s - loss: 0.0818 - accuracy: 0.7424 - 773ms/epoch - 4ms/step
# Epoch 9/30
# 197/197 - 1s - loss: 0.0803 - accuracy: 0.7098 - 775ms/epoch - 4ms/step
# Epoch 10/30
# 197/197 - 1s - loss: 0.0794 - accuracy: 0.6945 - 761ms/epoch - 4ms/step
# Epoch 11/30
# 197/197 - 1s - loss: 0.0779 - accuracy: 0.7303 - 779ms/epoch - 4ms/step
# Epoch 12/30
# 197/197 - 1s - loss: 0.0769 - accuracy: 0.7294 - 783ms/epoch - 4ms/step
# Epoch 13/30
# 197/197 - 1s - loss: 0.0776 - accuracy: 0.7332 - 754ms/epoch - 4ms/step
# Epoch 14/30
# 197/197 - 1s - loss: 0.0760 - accuracy: 0.6694 - 718ms/epoch - 4ms/step
# Epoch 15/30
# 197/197 - 1s - loss: 0.0750 - accuracy: 0.7079 - 727ms/epoch - 4ms/step
# Epoch 16/30
# 197/197 - 1s - loss: 0.0753 - accuracy: 0.7104 - 756ms/epoch - 4ms/step
# Epoch 17/30
# 197/197 - 1s - loss: 0.0735 - accuracy: 0.6979 - 754ms/epoch - 4ms/step
# Epoch 18/30
# 197/197 - 1s - loss: 0.0726 - accuracy: 0.6544 - 724ms/epoch - 4ms/step
# Epoch 19/30
# 197/197 - 1s - loss: 0.0726 - accuracy: 0.6656 - 784ms/epoch - 4ms/step
# Epoch 20/30
# 197/197 - 1s - loss: 0.0719 - accuracy: 0.7289 - 807ms/epoch - 4ms/step
# Epoch 21/30
# 197/197 - 1s - loss: 0.0728 - accuracy: 0.7179 - 773ms/epoch - 4ms/step
# Epoch 22/30
# 197/197 - 1s - loss: 0.0714 - accuracy: 0.7274 - 765ms/epoch - 4ms/step
# Epoch 23/30
# 197/197 - 1s - loss: 0.0704 - accuracy: 0.7255 - 771ms/epoch - 4ms/step
# Epoch 24/30
# 197/197 - 1s - loss: 0.0705 - accuracy: 0.7585 - 798ms/epoch - 4ms/step
# Epoch 25/30
# 197/197 - 1s - loss: 0.0703 - accuracy: 0.7411 - 805ms/epoch - 4ms/step
# Epoch 26/30
# 197/197 - 1s - loss: 0.0699 - accuracy: 0.7531 - 806ms/epoch - 4ms/step
# Epoch 27/30
# 197/197 - 1s - loss: 0.0689 - accuracy: 0.7107 - 796ms/epoch - 4ms/step
# Epoch 28/30
# 197/197 - 1s - loss: 0.0689 - accuracy: 0.7198 - 795ms/epoch - 4ms/step
# Epoch 29/30
# 197/197 - 1s - loss: 0.0676 - accuracy: 0.6874 - 785ms/epoch - 4ms/step
# Epoch 30/30
# 197/197 - 1s - loss: 0.0691 - accuracy: 0.7279 - 772ms/epoch - 4ms/step
# Done training. Testing model ...
# 105/105 - 1s - loss: 0.0573 - accuracy: 0.6016 - 719ms/epoch - 7ms/step
# Done!

# %% [markdown]
# Training on all 93 segments:

# %%
# IMPORT LIBRARIES:
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard
import time

# SETUP:   
# Prepare train data:
#range1 = [i for i in range(0,95)]
rangeI = np.arange(0,96)
rangeO = np.arange(0,93)#[76+1]
dataset_x = pd.read_csv('df.txt', usecols=rangeI, engine='python')
dataset_x = dataset_x.values
dataset_x = dataset_x.astype('float32')
x = np.reshape(dataset_x, (dataset_x.shape[0],1,dataset_x.shape[1]))
dataset_y = pd.read_csv('labels.txt', usecols=rangeO, engine='python')   
dataset_y = dataset_y.values
dataset_y = dataset_y.astype('float32')
#y = np.reshape(dataset_y, (dataset_y.shape[0],1,dataset_y.shape[1]))
y = np.reshape(dataset_y, (dataset_y.shape[0],dataset_y.shape[1]))
x_train = x
y_train = y 
# Prepare test data:
#x_test = pd.read_csv('test_ball.txt', usecols=rangeI, engine='python')
x_test = pd.read_csv('df_test.txt', usecols=rangeI, engine='python')
x_test = x_test.values
x_test = x_test.astype('float32')
x_test = np.reshape(x_test, (x_test.shape[0],1,x_test.shape[1]))
#y_test = pd.read_csv('test_ball.txt', usecols=[96], engine='python')
y_test = pd.read_csv('labels_test.txt', usecols=rangeO, engine='python')   
y_test = y_test.values
y_test = y_test.astype('float32')
y_test = np.reshape(y_test, (y_test.shape[0],y_test.shape[1]))
# Quick test:
#x_test = x_train
#y_test = y_train

num_in = x_train.shape[2]
num_out = y_train.shape[1]

# Build LSTM model:
model = keras.models.Sequential()
model.add(keras.Input(shape=(None, num_in))) #timesteps, seq_length.
#model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.LSTM(128, dropout=0.1))
model.add(layers.Dense(num_out, activation="sigmoid"))
#print(model.summary)

model.compile(
    loss = keras.losses.BinaryCrossentropy(from_logits=False),
    #optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    optimizer = keras.optimizers.Adam(lr=0.001, decay=1e-6),
    metrics = ["accuracy"]    
)

batchSize = 32
verbose = 2
# Train model:
print("Training model ...")
model.fit(x_train, y_train, batch_size=batchSize, epochs=30, verbose=verbose)

# Evaluate model:
print("Done training. Testing model ...")
model.evaluate(x_test, y_test, batch_size=batchSize, verbose=verbose)

# SAVE MODEL:
#model.save('models\tfmodel')

print("Done!")    
# END.
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Training model ...
# Epoch 1/30
# 197/197 - 3s - loss: 0.3097 - accuracy: 1.5911e-04 - 3s/epoch - 14ms/step
# Epoch 2/30
# 197/197 - 1s - loss: 0.1619 - accuracy: 0.0115 - 817ms/epoch - 4ms/step
# Epoch 3/30
# 197/197 - 1s - loss: 0.1229 - accuracy: 0.0603 - 833ms/epoch - 4ms/step
# Epoch 4/30
# 197/197 - 1s - loss: 0.0989 - accuracy: 0.0648 - 788ms/epoch - 4ms/step
# Epoch 5/30
# 197/197 - 1s - loss: 0.0848 - accuracy: 0.0563 - 740ms/epoch - 4ms/step
# Epoch 6/30
# 197/197 - 1s - loss: 0.0756 - accuracy: 0.0522 - 741ms/epoch - 4ms/step
# Epoch 7/30
# 197/197 - 1s - loss: 0.0714 - accuracy: 0.0461 - 736ms/epoch - 4ms/step
# Epoch 8/30
# 197/197 - 1s - loss: 0.0675 - accuracy: 0.0356 - 742ms/epoch - 4ms/step
# Epoch 9/30
# 197/197 - 1s - loss: 0.0652 - accuracy: 0.0325 - 779ms/epoch - 4ms/step
# Epoch 10/30
# 197/197 - 1s - loss: 0.0636 - accuracy: 0.0310 - 780ms/epoch - 4ms/step
# Epoch 11/30
# 197/197 - 1s - loss: 0.0612 - accuracy: 0.0304 - 773ms/epoch - 4ms/step
# Epoch 12/30
# 197/197 - 1s - loss: 0.0601 - accuracy: 0.0194 - 742ms/epoch - 4ms/step
# Epoch 13/30
# 197/197 - 1s - loss: 0.0592 - accuracy: 0.0243 - 785ms/epoch - 4ms/step
# Epoch 14/30
# 197/197 - 1s - loss: 0.0581 - accuracy: 0.0177 - 771ms/epoch - 4ms/step
# Epoch 15/30
# 197/197 - 1s - loss: 0.0580 - accuracy: 0.0146 - 775ms/epoch - 4ms/step
# Epoch 16/30
# 197/197 - 1s - loss: 0.0558 - accuracy: 0.0169 - 768ms/epoch - 4ms/step
# Epoch 17/30
# 197/197 - 1s - loss: 0.0559 - accuracy: 0.0177 - 761ms/epoch - 4ms/step
# Epoch 18/30
# 197/197 - 1s - loss: 0.0544 - accuracy: 0.0189 - 749ms/epoch - 4ms/step
# Epoch 19/30
# 197/197 - 1s - loss: 0.0545 - accuracy: 0.0183 - 771ms/epoch - 4ms/step
# Epoch 20/30
# 197/197 - 1s - loss: 0.0545 - accuracy: 0.0172 - 771ms/epoch - 4ms/step
# Epoch 21/30
# 197/197 - 1s - loss: 0.0539 - accuracy: 0.0154 - 779ms/epoch - 4ms/step
# Epoch 22/30
# 197/197 - 1s - loss: 0.0533 - accuracy: 0.0169 - 799ms/epoch - 4ms/step
# Epoch 23/30
# 197/197 - 1s - loss: 0.0525 - accuracy: 0.0162 - 841ms/epoch - 4ms/step
# Epoch 24/30
# 197/197 - 1s - loss: 0.0521 - accuracy: 0.0194 - 792ms/epoch - 4ms/step
# Epoch 25/30
# 197/197 - 1s - loss: 0.0527 - accuracy: 0.0213 - 776ms/epoch - 4ms/step
# Epoch 26/30
# 197/197 - 1s - loss: 0.0526 - accuracy: 0.0148 - 797ms/epoch - 4ms/step
# Epoch 27/30
# 197/197 - 1s - loss: 0.0517 - accuracy: 0.0204 - 785ms/epoch - 4ms/step
# Epoch 28/30
# 197/197 - 1s - loss: 0.0509 - accuracy: 0.0207 - 748ms/epoch - 4ms/step
# Epoch 29/30
# 197/197 - 1s - loss: 0.0505 - accuracy: 0.0180 - 741ms/epoch - 4ms/step
# Epoch 30/30
# 197/197 - 1s - loss: 0.0511 - accuracy: 0.0210 - 763ms/epoch - 4ms/step
# Done training. Testing model ...
# 105/105 - 1s - loss: 0.0399 - accuracy: 0.0200 - 646ms/epoch - 6ms/step
# Done!
